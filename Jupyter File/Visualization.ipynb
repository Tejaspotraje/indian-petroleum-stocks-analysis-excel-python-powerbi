# %% [markdown]
# # Visulization.

# %% [markdown]
# ## Importing libiries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("D:\Indian Peterolium Stocks Analysis Project\Output File\CSV file\Indian Petroleum Stocks Combined.csv")
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12,6)
plt.rcParams['font.size'] = 14
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['figure.titlesize'] = 20
plt.rcParams['figure.titleweight'] = 'bold'
plt.rcParams['figure.autolayout'] = True
plt.rcParams['savefig.dpi'] = 500

# %% [markdown]
# ## Starting visualistion.

# %% [markdown]
# ### Year-wise Average Closing Price Trend

# %%
year_avg = df.groupby('year')['close_price'].mean()
plt.figure(figsize=(12,6))
plt.plot(year_avg.index, year_avg.values, marker='o')
plt.title("Year-wise Average Closing Price", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("Close Price", size = 15, fontweight = "bold")
plt.grid(True)
plt.tight_layout()
# save the plot to file and then show
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\01_yearly_closing_price.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Market Cap Trend Over Years

# %%
year_mc = df.groupby('year')['market_cap'].mean()
plt.figure(figsize=(12,6))
plt.plot(year_mc.index, year_mc.values,marker='o')
plt.title("Market Cap Trend", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("Market Cap", size = 15, fontweight = "bold")
plt.grid(True)
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\02_yearly_market_cap.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Closing Price Distribution

# %%
plt.figure(figsize= (13,6))
plt.hist(df['close_price'], bins=20)
plt.title("Closing Price Distribution",size = 20 , fontweight = "bold")
plt.xlabel("Price",size = 15 , fontweight = "bold")
plt.ylabel("Frequency",size = 15 , fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\03_closing_price_distribution.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Company-wise Average Price

# %%
company_price = df.groupby('companies')['close_price'].mean()
plt.figure(figsize = (13,6))
plt.bar(company_price.index, company_price.values)
plt.xticks(rotation=30)
plt.title("Average Closing Price by Company", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\04_avg_closing_price_by_company.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Volatility Over Years

# %%
vol = df.groupby('year')['spread_(high-low)'].mean()
plt.figure(figsize=(12,6))
plt.plot(vol.index, vol.values)
plt.title("Volatility Trend", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("Spread (High-Low)", size = 15, fontweight = "bold")
plt.grid(True)  
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\05_volatility_trend.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### EPS Growth Trend

# %%
eps_growth = df.groupby('year')['eps_growth_%'].mean()
plt.figure(figsize=(12,6))
plt.plot(eps_growth.index, eps_growth.values)
plt.title("EPS Growth %", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("EPS Growth %", size = 15, fontweight = "bold")
plt.grid(True)  
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\06_eps_growth_trend.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### PE Ration Distribution

# %%
plt.figure(figsize=(13,6))
plt.hist(df['pe_ratio'], bins=15)
plt.title("PE Ratio Distribution",size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\07_pe_ratio_distribution.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Sector-wise Market Cap

# %%
sector_mc = df.groupby('sector')['market_cap'].mean()
plt.figure(figsize=(13,6))
plt.bar(sector_mc.index, sector_mc.values)
plt.title("Market Cap by Sector", size = 20, fontweight = "bold")
plt.xlabel("Sector", size = 15, fontweight = "bold")
plt.ylabel("Market Cap", size = 15, fontweight = "bold")    
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\08_market_cap_by_sector.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Year-wise Sales Growth

# %%
sales_growth = df.groupby('year')['sales_growth_%'].mean()
plt.figure(figsize=(12,6))
plt.plot(sales_growth.index, sales_growth.values)
plt.title("Sales Growth % Trend", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("Sales Growth %", size = 15, fontweight = "bold")
plt.grid(True)  
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\09_sales_growth_trend.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Net Profit Growth Trend

# %%
profit_growth = df.groupby('year')['net_profit_growth_%'].mean()
plt.figure(figsize=(12,6))
plt.plot(profit_growth.index, profit_growth.values)
plt.title("Net Profit Growth %", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("Net Profit Growth %", size = 15, fontweight = "bold")
plt.grid(True)  
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\10_net_profit_growth_trend.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Company-wise Average Closing Price

# %%
plt.figure(figsize=(13,6))
sns.barplot(data=df, x='companies', y='close_price', estimator='mean')
plt.title("Avg Closing Price by Company", size = 20, fontweight = "bold")
plt.xlabel("Companies", size = 15, fontweight = "bold")
plt.ylabel("Avg Closing Price", size = 15, fontweight = "bold")
plt.tight_layout()
plt.xticks(rotation=30)
plt.title("Avg Closing Price")
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\11_avg_closing_price_barplot.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Company-wise Average Closing Price

# %%
sns.barplot(data=df, x='sector', y='market_cap', estimator='mean')
plt.title("Market Cap by Sector")
plt.xlabel("Sector")
plt.ylabel("Market Cap")
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\12_market_cap_by_sector_barplot.png", bbox_inches='tight', dpi=300)   
plt.show()

# %% [markdown]
# ### Sales vs Profit Growth

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df, x='year', y='close_price', hue='companies')       
sns.scatterplot(data=df, x='sales_growth_%', y='net_profit_growth_%')
plt.title("Sales Growth % vs Net Profit Growth %", size = 20, fontweight = "bold")
plt.xlabel("Sales Growth %", size = 15, fontweight = "bold")
plt.ylabel("Net Profit Growth %", size = 15, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\13_sales_vs_profit_growth.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Closing Prise Trend

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df, x='year', y='close_price', hue='companies')
plt.title("Closing Price Trend")
plt.grid(True)
plt.title("Closing Price Trend", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")  
plt.ylabel("Closing Price", size = 15, fontweight = "bold")
plt.tight_layout()  
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\14_closing_price_trend_by_company.png", bbox_inches='tight', dpi=300) 
plt.show()

# %% [markdown]
# ### Average PE ratio of the Companies.

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=df, x='companies', y='pe_ratio')
plt.axhline(df['pe_ratio'].mean(), linestyle='--')
plt.title("PE Ratio with Mean", size = 20, fontweight = "bold")
plt.xlabel("Companies", size = 15, fontweight = "bold")
plt.ylabel("PE Ratio", size = 15, fontweight = "bold")
plt.tight_layout()
plt.xticks(rotation=30)
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\15_pe_ratio_boxplot.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Sales vs Profit growth of Comapnies

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(
    data=df,
    x='sales_growth_%',
    y='net_profit_growth_%',
    hue='companies',
    style='sector'
)
plt.xlabel("Sales Growth %", size = 15, fontweight = "bold")
plt.ylabel("Net Profit Growth %", size = 15, fontweight = "bold")
plt.title("Sales vs Profit Growth", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\16_sales_vs_profit_growth.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Market Cap Trend by Years.

# %%
plt.figure(figsize= (12,6))
sns.lineplot(data=df, x='year', y='market_cap', hue='companies')
plt.grid(True)
plt.title("Market Cap Trend", size = 20, fontweight = "bold")
plt.xlabel("Year", size = 15, fontweight = "bold")
plt.ylabel("Market Cap", size = 15, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\17_market_cap_trend_by_company.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### CAGR of Closing Price by Company

# %%
plt.figure(figsize= (12,6))
sns.barplot(
    data=df[['companies','cagr_close_price']].drop_duplicates(),
    x='companies',
    y='cagr_close_price'
)
plt.title("CAGR of Closing Price by Company", size = 20, fontweight = "bold")   
plt.xlabel("Companies", size = 15, fontweight = "bold")
plt.ylabel("CAGR of Closing Price", size = 15, fontweight = "bold")
plt.tight_layout()
plt.xticks(rotation=30)
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\18_cagr_closing_price_by_company.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### EPS Distribution by Company

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=df, x='companies', y='eps')
plt.title("EPS Distribution by Company",size = 20, fontweight = "bold" )
plt.xlabel("Companies", size = 15, fontweight = "bold")
plt.ylabel("EPS", size = 15, fontweight = "bold")
plt.tight_layout()
plt.xticks(rotation=30)
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\19_eps_distribution_by_company.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Market Cap Density.

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(df['market_cap'], fill=True)
plt.xlabel("Market Cap", size = 15, fontweight = "bold")
plt.ylabel("Density", size = 15, fontweight = "bold")   
plt.tight_layout()
plt.title("Market Cap Density", size = 20, fontweight = "bold")
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\20_market_cap_density.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Price vs EPS

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x='eps', y='price', hue='companies')
plt.xlabel("EPS", size = 15, fontweight = "bold")
plt.ylabel("Price", size = 15, fontweight = "bold") 
plt.title("Price vs EPS", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\21_price_vs_eps.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Market Cap Impact.

# %%
plt.figure(figsize=(12,6))
plt.scatter(
    df['price'],
    df['eps'],
    s=df['market_cap'] / 1e10,
    alpha=0.6
)
plt.xlabel("Price", size = 15, fontweight = "bold")
plt.ylabel("EPS", size = 15, fontweight = "bold")
plt.title("Bubble Chart: Market Cap Impact", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\22_bubble_chart_market_cap.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Multi Plot Insight.

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df[['price', 'eps', 'pe_ratio', 'market_cap']])
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\23_pairplot_stocks.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Market Cap Contribution by Sector

# %%
plt.figure(figsize=(12,6))
sector_cap = df.groupby('sector')['market_cap'].mean()
plt.pie(sector_cap, labels=sector_cap.index, autopct='%1.1f%%')
plt.title("Market Cap Contribution by Sector", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\24_market_cap_contribution_by_sector.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### CAGR Ranking by Companies.

# %%
cagr_df = df[['companies', 'cagr_close_price']].drop_duplicates()

plt.barh(cagr_df['companies'], cagr_df['cagr_close_price'])
plt.title("CAGR Ranking by Company", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\25_cagr_ranking_by_company.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Operation Margin Comparison Between Companies.

# %%
opm_avg = df.groupby('companies')['operating_margin_%'].mean()

plt.hlines(y=opm_avg.index, xmin=0, xmax=opm_avg.values)
plt.plot(opm_avg.values, opm_avg.index, "o")
plt.title("Operating Margin Comparison")
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(12,6))

corr = df[['price','eps','pe_ratio','market_cap','sales_growth_%','net_profit_growth_%']].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap", size = 20, fontweight = "bold" )
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\26_correlation_heatmap.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Growth Composition Over Years

# %%
plt.figure(figsize=(12,6))

year_growth = df.groupby('year')[['sales_growth_%','net_profit_growth_%']].mean()

plt.stackplot(
    year_growth.index,
    year_growth['sales_growth_%'],
    year_growth['net_profit_growth_%'],
    labels=['Sales Growth', 'Profit Growth']
)
plt.legend()
plt.title("Growth Composition Over Years", size = 20, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\27_growth_composition_over_years.png", bbox_inches='tight', dpi=300)  
plt.show()

# %% [markdown]
# ### Price Volatility Over Years.

# %%
plt.figure(figsize=(12,6))

price_stats = df.groupby('year')['close_price'].agg(['mean','std'])

plt.errorbar(
    price_stats.index,
    price_stats['mean'],
    yerr=price_stats['std'],
    fmt='o'
)
plt.title("Price Volatility Over Years", size = 20, fontweight = "bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PE Ratio Spread

# %%
sns.stripplot(data=df, x='companies', y='pe_ratio', jitter=True)
plt.title("PE Ratio Spread")
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\28_pe_ratio_spread.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### EPS Comparision by Companies.

# %%
sns.swarmplot(data=df, x='companies', y='eps')
plt.title("EPS Comparison")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ### EPS VS Price

# %%
sns.regplot(data=df, x='eps', y='price')
plt.title("Regression: EPS vs Price")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\29_regression_eps_vs_price.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Market Cap VS Price.

# %%
plt.figure(figsize=(12,6))
sns.jointplot(data=df, x='price', y='market_cap', kind='scatter')
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\30_jointplot_price_vs_market_cap.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### ECDF of Cloasing Price

# %%
sns.ecdfplot(data=df, x='close_price')
plt.title("ECDF of Closing Price")
plt.xlabel("Closing Price")
plt.ylabel("ECDF")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\31_ecdf_closing_price.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Average EPS by Company.

# %%
sns.pointplot(data=df, x='companies', y='eps', estimator='mean')
plt.xticks(rotation=30)
plt.title("Average EPS by Company")
plt.xlabel("Companies", size = 15, fontweight = "bold")
plt.ylabel("Average EPS", size = 15, fontweight = "bold")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\34_avg_eps_by_company.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### PE Ratio Density

# %%
sns.kdeplot(df['pe_ratio'], fill=True)
sns.rugplot(df['pe_ratio'])
plt.title("PE Ratio Density with Rug Plot")
plt.xlabel("PE Ratio")
plt.ylabel("Density")   
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\32_pe_ratio_density_rugplot.png", bbox_inches='tight', dpi=300)   
plt.show()

# %% [markdown]
# ### Private and Public Sector Market Cap.

# %%
plt.figure(figsize=(12,6))
g = sns.FacetGrid(df, col='sector', height=4)
g.map(sns.lineplot, 'year', 'market_cap')
g.set_titles("{col_name} Sector")
plt.tight_layout()
plt.savefig(r"D:\Indian Peterolium Stocks Analysis Project\Screenshot\33_facetgrid_market_cap_by_sector.png", bbox_inches='tight', dpi=300) 
plt.show()
